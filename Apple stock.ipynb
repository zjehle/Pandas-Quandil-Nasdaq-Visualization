# %%
import pandas as pd
import numpy as np
import requests
import csv

# %%
#url= 'http://www.quandl.com/api/v3/datasets/WIKI/AAPL.csv'

#response= requests.get(url)
#reader=csv.reader("~/Downloads/WIKI-AAPL.csv")
#for row in reader: 
  #  print(row)
    
df=pd.read_csv("~/Downloads/WIKI-AAPL.csv")
df
# Out:
#             Date    Open    High     Low    Close      Volume  Ex-Dividend  \
# 0     2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
# 1     2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2     2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 3     2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 4     2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# ...          ...     ...     ...     ...      ...         ...          ...
# 9395  1980-12-18   26.63   26.75   26.63   26.630    327900.0          0.0
# 9396  1980-12-17   25.87   26.00   25.87   25.870    385900.0          0.0
# 9397  1980-12-16   25.37   25.37   25.25   25.250    472000.0          0.0
# 9398  1980-12-15   27.38   27.38   27.25   27.250    785200.0          0.0
# 9399  1980-12-12   28.75   28.87   28.75   28.750   2093900.0          0.0
#
# ...

# %%
df.sort_values('Date').plot(x='Date',y='Adj. Close',kind='line',figsize=(20,5))

# %%
#url= 'http://www.quandl.com/api/v3/datasets/WIKI/AAPL.csv?api_key=&start_date=2018-01-01'
url='https://www.quandl.com/api/v3/datatables/SHARADAR/SEP.csv?date.gte=2020-01-01&date.lte=2020-10-20&ticker=AAPL&api_key='

with requests.Session() as s:
    response= s.get(url)
    decoded_content=response.content.decode('utf-8')
    reader=csv.reader(decoded_content.splitlines(),delimiter=',')
    data_list= list(reader)
    for row in data_list: 
        print(row)
# Out:
# ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'dividends', 'closeunadj', 'lastupdated']
# ['AAPL', '2020-10-19', '119.96', '120.419', '115.66', '115.98', '119366165.0', '0.0', '115.98', '2020-10-19']
# ['AAPL', '2020-10-16', '121.28', '121.548', '118.81', '119.02', '115393808.0', '0.0', '119.02', '2020-10-16']
# ['AAPL', '2020-10-15', '118.72', '121.2', '118.15', '120.71', '111278956.0', '0.0', '120.71', '2020-10-15']
# ['AAPL', '2020-10-14', '121.0', '123.03', '119.62', '121.19', '150268765.0', '0.0', '121.19', '2020-10-14']
# ['AAPL', '2020-10-13', '125.27', '125.39', '119.65', '121.1', '260497701.0', '0.0', '121.1', '2020-10-13']
# ['AAPL', '2020-10-12', '120.06', '125.18', '119.284', '124.4', '236262242.0', '0.0', '124.4', '2020-10-12']
# ['AAPL', '2020-10-09', '115.28', '117.0', '114.92', '116.97', '100506865.0', '0.0', '116.97', '2020-10-09']
# ['AAPL', '2020-10-08', '116.25', '116.4', '114.59', '114.97', '82322071.0', '0.0', '114.97', '2020-10-08']
# ...
